# %% [markdown]
# <a href="https://colab.research.google.com/github/EdVKu/Econophysics_Projects/blob/main/Ej1_GOE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demostración Computacional de Ley de Winger de Semi-Circulo:
#
# La Ley de Winger de Semicírculo postula que, dado un ensamble de matrices aleatorias $\{A_i\}_{i = 0}^{m},\ A_i \in M_{n\times n}(F)$ sobre un campo, entonces su distribución de Eigenvalores $\rho(E)$ se aproxima a la siguiente función:
#
# $$\rho(E) =\frac{2\sqrt{R²+E²}}{\pi R²}$$
#
# Para una n suficientemente grande.
#
# Se llevará a cabo la demostración computacional con $n \in \{5,20,30,100\}$

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(1100)
x = []
def goe(n):
    x = np.random.normal(0,1,(n,n))
    x = np.sqrt(0.5)*(x+np.transpose(x))
    return x

# %%
# Generar un conjunto de m GOEs de dimensión n
def multgoe(a,b):
    p = []
    for i in range(0,a):
        p.append(goe(b))
    return p
#Obtener eigenvalores y guardar los mxn eigenvalores en un sólo vector columna



n5 =multgoe(50, 5)
n20 = multgoe(50, 20)
n30 = multgoe(50, 30)
n100 = multgoe(50, 100)

def eig(m):
    p = []

    for i in range(0, np.shape(m)[0]):
        media = np.mean(np.linalg.eig(m)[0][i])
        desvest = np.std(np.linalg.eig(m)[0][i])
        for j in range(0, np.shape(m)[1]):
            p.append((float(np.linalg.eig(m)[0][i][j])-media)/desvest)
    return np.transpose(p)

#Comparar eigenvalores con ley de Winger de semicírculo
# Out:
# array([ 1.54012599,  0.70300319, -0.20719676, -0.92216028, -1.11377213,
#         1.29403098,  0.80744885,  0.08811999, -1.46125003, -0.72834978,
#        -1.21971157, -1.06912303,  1.35294085,  0.69253777,  0.24335598,
#        -1.33666581, -0.81648032, -0.05534768,  1.33326502,  0.87522879,
#         1.41692569,  0.88902754, -1.21302294, -0.8046111 , -0.28831919,
#         1.51127833, -1.33392083, -0.82220656,  0.16001415,  0.48483491,
#        -1.529199  ,  1.39866308,  0.63528243,  0.04285862, -0.54760513,
#         1.6572274 , -1.35644137, -0.51489018, -0.14357911,  0.35768326,
#         1.43442279, -1.25336386, -0.8646707 , -0.09989106,  0.78350283,
#         1.57814412, -1.34208659,  0.5856523 , -0.52848268, -0.29322714,
#         1.54982104, -1.37099421, -0.72291574,  0.42665053,  0.11743839,
#        -1.36116132,  1.37548929,  0.90194702, -0.56297239, -0.3533026 ,
#        -1.50998823,  1.35187238, -0.66480563,  0.17501813,  0.64790335,
#         1.25761447,  0.93754708,  0.0131773 , -0.87960603, -1.32873282,
#         1.38267829,  0.98907407, -1.12493984, -0.44014029, -0.80667223,
#        -1.65226339, -0.5968576 ,  1.08782985,  0.74814834,  0.4131428 ,
#        -1.2428094 , -0.77149304, -0.29458243,  0.92209592,  1.38678895,
#        -1.79079572,  1.05652667,  0.67208047,  0.36514235, -0.30295377,
#        -1.93716623,  0.18699913,  0.24117611,  0.84316761,  0.66582338,
#        -1.55487999, -0.64184199,  1.29417592,  0.24127176,  0.6612743 ,
#        -1.47831095,  1.5177802 , -0.52104706,  0.48927569, -0.00769788,
#        -1.60001556, -0.65088355,  1.14779877,  0.76420436,  0.33889598,
#        -1.70476528,  1.31670098, -0.31019078,  0.44931602,  0.24893906,
#        -1.54254417,  1.39282843, -0.61630129,  0.32231206,  0.44370497,
#         1.61143939, -1.25024603, -0.81716749,  0.41295873,  0.0430154 ,
#         1.52094043,  0.71918627, -0.2386371 , -1.23482097, -0.76666864,
#         1.36709301,  0.8350904 , -1.3583855 , -0.76283303, -0.08096488,
#         1.74260924, -1.30420783,  0.18489041, -0.44188443, -0.18140739,
#        -1.33775511, -0.91821262,  1.37873442,  0.23660289,  0.64063041,
#         1.49336843, -1.46554334, -0.58862865,  0.52360894,  0.03719462,
#        -1.33720428, -0.90181456,  0.05753979,  1.17984322,  1.00163584,
#        -1.92663586,  0.11256075,  0.93371996,  0.52978447,  0.35057069,
#         1.4278556 , -1.37991039, -0.80099285,  0.63337572,  0.11967192,
#        -1.38724032, -0.82389013,  0.02831905,  1.0088387 ,  1.17397269,
#        -1.44075729,  1.47660225,  0.66208363, -0.52497185, -0.17295674,
#        -1.74056255, -0.3986514 ,  0.30239602,  1.04710569,  0.78971223,
#        -1.71752421,  1.16565713,  0.74182132, -0.34298305,  0.15302881,
#         1.49416151,  0.7907792 , -0.25733824, -1.11464957, -0.9129529 ,
#         1.84867269, -1.0564072 , -0.63885624,  0.07578898, -0.22919823,
#        -1.5691046 , -0.65675267,  1.21843228,  0.2643833 ,  0.74304169,
#        -1.28234743, -0.98671406,  1.28210439,  0.13911532,  0.84784178,
#        -1.30624123, -1.107286  ,  0.55284304,  0.80595692,  1.05472727,
#         1.77191241, -1.2797612 ,  0.1384046 , -0.36313981, -0.26741599,
#        -1.52812029, -0.52707056, -0.04736311,  0.75595073,  1.34660323,
#         1.60523087, -1.30789433, -0.75173111,  0.0783527 ,  0.37604187,
#        -1.22018387, -0.73348863, -0.3934415 ,  1.35227107,  0.99484294,
#        -1.58891789, -0.6039406 ,  0.21894138,  0.7477035 ,  1.22621362,
#         1.73294184, -1.30589859,  0.19610723, -0.13992858, -0.4832219 ,
#         1.51666827, -1.38125299, -0.75826366,  0.20436411,  0.41848426,
#        -1.63691883,  1.24985046, -0.40489793,  0.02126795,  0.77069834])

# %%
xc = np.linspace(-2, 2, num=2000)
y = 2*np.sqrt(4-xc**2)/(np.pi*4)

# %%
Eig = eig(n5)

plt.hist(Eig,bins=50, density = True)
plt.plot(xc,y)

# %%
Eig = eig(n20)

plt.hist(Eig,bins=50, density = True)
plt.plot(xc,y)

# %%
Eig = eig(n30)
plt.hist(Eig,bins=50, density = True)
plt.plot(xc,y)

# %%
Eig = eig(n100)

plt.hist(Eig,bins=50, density = True)
plt.plot(xc,y)
